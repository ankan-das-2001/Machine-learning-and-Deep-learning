# %% [markdown]
# # Univariate Selection
#
# Filter test

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

# %%
data  =pd.read_csv("train.csv")
print(data.head())
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
X=data.iloc[:,0:20]
y = data.iloc[:,-1]

# %%
y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %%
# apply selectKBest top 10 feature
best_feature = SelectKBest(score_func = chi2, k=10)

# %%
fit = best_feature.fit(X,y)

# %%
dfscore = pd.DataFrame(fir.scores_)
dfcolumns = pd.DataFrame(X.columns)

# %%
featureScore = pd.concat([dfcolumns,dfscore],axis=1)

# %%
featureScore.columns = ["feature","score"]

# %%
featureScore.sort_values(by='score', ascending=False)
# Out:
#           feature          score
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878
# 10             pc       9.186054
# 9         n_cores       9.097556
# 18   touch_screen       1.928429
# 5          four_g       1.521572
# 7           m_dep       0.745820
# 1            blue       0.723232
# 2     clock_speed       0.648366
# 3        dual_sim       0.631011
# 19           wifi       0.422091
# 17        three_g       0.327643

# %% [markdown]
# # Feature importance

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# %%
model = RandomForestClassifier()

# %%
model.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
model.feature_importances_
# Out:
# array([0.07184222, 0.00631585, 0.02702867, 0.00663727, 0.02492258,
#        0.00640888, 0.03614853, 0.0253279 , 0.03968618, 0.02346359,
#        0.02761962, 0.05702938, 0.05736322, 0.48501465, 0.0267503 ,
#        0.02842468, 0.03003512, 0.00554474, 0.00767532, 0.0067613 ])

# %%
feature_importance = pd.DataFrame(model.feature_importances_, index=X.columns, columns=["importance"])

# %%
feature_importance = feature_importance.sort_values(by="importance", ascending=False)

# %%
plt.figure(figsize=(30,10))
plt.bar(feature_importance.index, feature_importance["importance"])
plt.show()

# %% [markdown]
# # Correlation based method

# %%
data_corr = data.corr()

# %%
data_corr
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(30,20))
sns.heatmap(data_corr,annot=True)
plt.show()

# %% [markdown]
# # Check the model performance

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import cross_val_score

# %%
rfc = RandomForestClassifier()

# %%
score = cross_val_score(rfc,X,y, cv=10)

# %%
score.mean()
# Out:
# 0.884

# %%
four_feature=["ram","px_height","battery_power","px_width"]

# %%
X[four_feature]
# Out:
#        ram  px_height  battery_power  px_width
# 0     2549         20            842       756
# 1     2631        905           1021      1988
# 2     2603       1263            563      1716
# 3     2769       1216            615      1786
# 4     1411       1208           1821      1212
# ...    ...        ...            ...       ...
# 1995   668       1222            794      1890
# 1996  2032        915           1965      1965
# 1997  3057        868           1911      1632
# 1998   869        336           1512       670
# 1999  3919        483            510       754
#
# [2000 rows x 4 columns]

# %%
new_score = cross_val_score(rfc,X[four_feature],y,cv=10).mean()

# %%
new_score
# Out:
# 0.9175000000000001

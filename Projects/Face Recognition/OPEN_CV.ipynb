# %%
import cv2

# %% [markdown]
# # Reading a image using opencv

# %%
img = cv2.imread('photo.jpg')#By default bgr is displayed

newImg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow(newImg)

# %%
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[ 93  57 223]
#   [ 88  54 219]
#   [ 83  48 216]
#   ...
#   [ 67  42 192]
#   [ 63  40 192]
#   [ 60  37 189]]
#
#  [[ 98  61 225]
#   [ 90  55 219]
#   [ 84  50 215]
#   ...
#   [ 67  43 191]
#   [ 60  37 189]
#   [ 54  33 185]]
#
#  [[ 99  62 226]
#   [ 91  55 221]
#   [ 85  50 218]
#   ...
#   [ 65  43 191]
#   [ 55  35 184]
#   [ 52  31 183]]]

# %%
 cv2.imshow('ankan',img)
 cv2.waitKey(11000)
 cv2.destroyAllWindows()
